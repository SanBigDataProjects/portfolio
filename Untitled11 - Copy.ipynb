# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

# %%
data=pd.read_csv('normal_skew.csv')
data
# Out:
#      normal_example  skewed_example
# 0          0.068676        2.023029
# 1         -0.143016        0.330508
# 2         -0.316584        0.140008
# 3          0.979202        0.255954
# 4         -0.739245        0.122830
# ..              ...             ...
# 251       -0.437291        0.291538
# 252        0.679831        0.849879
# 253       -1.039813        1.607979
# 254       -0.583792        1.417038
# 255       -0.385109        0.244595
#
# [256 rows x 2 columns]

# %%
stats.probplot(data['normal_example'])
plt.show()

# %%
stats.probplot(data['skewed_example'])
# Out:
# ((array([-2.78167673, -2.48033726, -2.30929542, -2.18719118, -2.09097899,
#          -2.01094445, -1.94203634, -1.88127825, -1.82676271, -1.77719092,
#          -1.73163703, -1.68941679, -1.65000965, -1.61300998, -1.5780953 ,
#          -1.54500483, -1.51352455, -1.48347653, -1.45471122, -1.42710163,
#          -1.40053898, -1.37492933, -1.35019097, -1.3262524 , -1.3030506 ,
#          -1.28052982, -1.25864042, -1.23733802, -1.21658279, -1.19633881,
#          -1.17657358, -1.15725761, -1.13836404, -1.11986832, -1.10174797,
#          -1.08398233, -1.06655239, -1.04944059, -1.03263068, -1.01610762,
#          -0.99985741, -0.98386703, -0.96812435, -0.95261801, -0.93733741,
#          -0.9222726 , -0.90741425, -0.89275357, -0.87828231, -0.86399268,
#          -0.84987734, -0.83592933, -0.82214208, -0.80850936, -0.79502528,
#          -0.78168423, -0.76848088, -0.75541015, -0.74246722, -0.7296475 ,
#          -0.71694658, -0.70436028, -0.69188459, -0.67951566, -0.66724983,
# ...

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 6))


# Q-Q plot for normal_example
stats.probplot(data['normal_example'], dist="norm", plot=ax[0])
#ax[0].set_title('Q-Q plot for normal_example')

# Q-Q plot for skewed_example
stats.probplot(data['skewed_example'], dist="norm", plot=ax[1])
#ax[1].set_title('Q-Q plot for skewed_example')

# Show the plots
plt.show()
